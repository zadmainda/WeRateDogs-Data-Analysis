# %%
import pandas as pd
import requests
import os
import glob
import json

# %%
archives = pd.read_csv('twitter-archive-enhanced.csv')

# %%
#Make a new folder to hold downloaded image-predictions tsv file
folder = 'Predictions'
if not os.path.exists(folder):
    os.makedirs(folder)

# %%
#Download file using the requests library 
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)

# %%
#write the contents of the response into a file in the Predictions folder
with open(os.path.join(folder, url.split('/')[-1]), mode='wb') as file:
    file.write(response.content)

# %% [markdown]
# Confirm the contents of the `Predictions` folder:

# %%
os.listdir('Predictions')
# Out:
# ['image-predictions.tsv']

# %%
#Read Data from the Image Predictions file into a dataframe
predictions = pd.read_csv('Predictions\image-predictions.tsv', sep='\t')

# %%
#Empty List that will hold the JSON data:
del(json_list)

# %%
json_list = []

# %%
#Reading JSON Data from a Text File
for tweet_file in glob.glob('*.txt'):
    with open(tweet_file, encoding='utf-8') as file:
        for line in file:
            txt_obj = file.readline()
            tweet_obj = json.loads(txt_obj)
            json_list.append({'tweet_id' : tweet_obj['id'], 'created_at' : tweet_obj['created_at'], 'retweet_count' : tweet_obj['retweet_count'],'favorite_count' : tweet_obj['favorite_count'],'followers_count' : tweet_obj['user']['followers_count']})

# %%
print(json_list)
# Out:
# [{'tweet_id': 892177421306343426, 'created_at': 'Tue Aug 01 00:17:27 +0000 2017', 'retweet_count': 6514, 'favorite_count': 33819, 'followers_count': 3200889}, {'tweet_id': 891689557279858688, 'created_at': 'Sun Jul 30 15:58:51 +0000 2017', 'retweet_count': 8964, 'favorite_count': 42908, 'followers_count': 3200889}, {'tweet_id': 891087950875897856, 'created_at': 'Sat Jul 29 00:08:17 +0000 2017', 'retweet_count': 3261, 'favorite_count': 20562, 'followers_count': 3200889}, {'tweet_id': 890729181411237888, 'created_at': 'Fri Jul 28 00:22:40 +0000 2017', 'retweet_count': 16716, 'favorite_count': 56848, 'followers_count': 3200889}, {'tweet_id': 890240255349198849, 'created_at': 'Wed Jul 26 15:59:51 +0000 2017', 'retweet_count': 7711, 'favorite_count': 32467, 'followers_count': 3200889}, {'tweet_id': 889880896479866881, 'created_at': 'Tue Jul 25 16:11:53 +0000 2017', 'retweet_count': 5156, 'favorite_count': 28268, 'followers_count': 3200889}, {'tweet_id': 889638837579907072, 'created_at': 'Tue Jul 25 00:10:02 +0000 2017', 'retweet_count': 4735, 'favorite_count': 27672, 'followers_count': 3200889}, {'tweet_id': 889278841981685760, 'created_at': 'Mon Jul 24 00:19:32 +0000 2017', 'retweet_count': 5637, 'favorite_count': 25652, 'followers_count': 3200889}, {'tweet_id': 888804989199671297, 'created_at': 'Sat Jul 22 16:56:37 +0000 2017', 'retweet_count': 4559, 'favorite_count': 26080, 'followers_count': 3200889}, {'tweet_id': 888078434458587136, 'created_at': 'Thu Jul 20 16:49:33 +0000 2017', 'retweet_count': 3653, 'favorite_count': 22201, 'followers_count': 3200889}, {'tweet_id': 887517139158093824, 'created_at': 'Wed Jul 19 03:39:09 +0000 2017', 'retweet_count': 12082, 'favorite_count': 46959, 'followers_count': 3200890}, {'tweet_id': 887343217045368832, 'created_at': 'Tue Jul 18 16:08:03 +0000 2017', 'retweet_count': 10737, 'favorite_count': 34222, 'followers_count': 3200890}, {'tweet_id': 886983233522544640, 'created_at': 'Mon Jul 17 16:17:36 +0000 2017', 'retweet_count': 8084, 'favorite_count': 35859, 'followers_count': 3200890}, {'tweet_id': 886680336477933568, 'created_at': 'Sun Jul 16 20:14:00 +0000 2017', 'retweet_count': 4610, 'favorite_count': 22798, 'followers_count': 3200890}, {'tweet_id': 886267009285017600, 'created_at': 'Sat Jul 15 16:51:35 +0000 2017', 'retweet_count': 4, 'favorite_count': 117, 'followers_count': 3200890}, {'tweet_id': 886054160059072513, 'created_at': 'Sat Jul 15 02:45:48 +0000 2017', 'retweet_count': 108, 'favorite_count': 0, 'followers_count': 3200890}, {'tweet_id': 885528943205470208, 'created_at': 'Thu Jul 13 15:58:47 +0000 2017', 'retweet_count': 6683, 'favorite_count': 36689, 'followers_count': 3200890}, {'tweet_id': 885311592912609280, 'created_at': 'Thu Jul 13 01:35:06 +0000 2017', 'retweet_count': 19297, 'favorite_count': 0, 'followers_count': 3200890}, {'tweet_id': 884925521741709313, 'created_at': 'Wed Jul 12 00:01:00 +0000 2017', 'retweet_count': 16439, 'favorite_count': 68152, 'followers_count': 3200890}, {'tweet_id': 884562892145688576, 'created_at': 'Tue Jul 11 00:00:02 +0000 2017', 'retweet_count': 5100, 'favorite_count': 24765, 'followers_count': 3200890}, {'tweet_id': 884247878851493888, 'created_at': 'Mon Jul 10 03:08:17 +0000 2017', 'retweet_count': 21298, 'favorite_count': 74423, 'followers_count': 3200890}, {'tweet_id': 883838122936631299, 'created_at': 'Sun Jul 09 00:00:04 +0000 2017', 'retweet_count': 3586, 'favorite_count': 22349, 'followers_count': 3200890}, {'tweet_id': 883360690899218434, 'created_at': 'Fri Jul 07 16:22:55 +0000 2017', 'retweet_count': 3825, 'favorite_count': 22986, 'followers_count': 3200890}, {'tweet_id': 882992080364220416, 'created_at': 'Thu Jul 06 15:58:11 +0000 2017', 'retweet_count': 4122, 'favorite_count': 24445, 'followers_count': 3200890}, {'tweet_id': 882627270321602560, 'created_at': 'Wed Jul 05 15:48:34 +0000 2017', 'retweet_count': 6342, 'favorite_count': 28382, 'followers_count': 3200890}, {'tweet_id': 882045870035918850, 'created_at': 'Tue Jul 0 ...

# %%
x = pd.DataFrame.from_dict(json_list)

# %%
x.tail()
# Out:
#                 tweet_id                      created_at  retweet_count  \
# 1172  666057090499244032  Mon Nov 16 00:55:59 +0000 2015            146
# 1173  666051853826850816  Mon Nov 16 00:35:11 +0000 2015            879
# 1174  666049248165822465  Mon Nov 16 00:24:50 +0000 2015             41
# 1175  666033412701032449  Sun Nov 15 23:21:54 +0000 2015             47
# 1176  666020888022790149  Sun Nov 15 22:32:08 +0000 2015            532
#
#       favorite_count  followers_count
# 1172             304          3201018
# 1173            1253          3201018
# 1174             111          3201018
# 1175             128          3201018
# 1176            2535          3201018

# %%
archives
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# ...                         ...
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator      name doggo floofer pupper puppo
# 0                     10   Phineas  None    None   None  None
# 1                     10     Tilly  None    None   None  None
# 2                     10    Archie  None    None   None  None
# 3                     10     Darla  None    None   None  None
# 4                     10  Franklin  None    None   None  None
# ...                  ...       ...   ...     ...    ...   ...
# 2351                  10      None  None    None   None  None
# 2352                  10         a  None    None   None  None
# 2353                  10         a  None    None   None  None
# 2354                  10         a  None    None   None  None
# 2355                  10      None  None    None   None  None
#
# [2356 rows x 17 columns]
